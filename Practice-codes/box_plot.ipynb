# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
timetaken = pd.Series([50,45,52,63,70,21,56,68,54,57,35,62,65,92,32])
plt.boxplot(timetaken)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2fa252cf5f0>,
#   <matplotlib.lines.Line2D at 0x2fa2530a7b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2fa2530aa50>,
#   <matplotlib.lines.Line2D at 0x2fa2530ad50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2fa2530a2a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2fa2530b050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2fa2530b320>],
#  'means': []}
