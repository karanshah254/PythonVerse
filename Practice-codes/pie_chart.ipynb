# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
values = [305, 201, 805, 35, 436]
l = ["Food", "Travel", "Accomodation", "Misc", "Shoping"]
c = ["b", "g", "r", "c", "m"]
e = [0, 0.2, 0, 0, 0]
plt.pie(values, colors=c, labels=l, explode=e, autopct='%1.1f%%', shadow=True)
plt.show()
